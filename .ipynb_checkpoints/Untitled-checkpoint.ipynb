# %%
# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api
import pandas as pd
import plotly.plotly as py


py.sign_in('jlarsch', 'kGjRfd3mGhMonEzD2K6k')

df = pd.read_csv('https://plot.ly/~Dreamshot/5718/electoral-college-votes-by-us-state/.csv')

for col in df.columns:
    df[col] = df[col].astype(str)
df.columns = [ "votes","state"]
df
# Out:
#    votes state
# 0      3    DE
# 1      3    VT
# 2      3    ND
# 3      3    SD
# 4      3    MT
# 5      3    WY
# 6      3    AK
# 7      3    DC
# 8      4    NH
# 9      4    RI
# 10     4    ME
# 11     4    ID
# 12     4    HI
# 13     5    WV
# 14     5    NE
# 15     5    NM
# 16     6    MS
# 17     6    AR
# 18     6    IA
# 19     6    KS
# 20     6    NV
# 21     6    UT
# 22     7    CT
# 23     7    OR
# 24     7    OK
# 25     8    KY
# 26     8    LA
# 27     9    SC
# 28     9    AL
# 29     9    CO
# 30    10    MD
# 31    10    MO
# 32    10    WI
# 33    10    MN
# 34    11    MA
# 35    11    TN
# 36    11    IN
# 37    11    AZ
# 38    12    WA
# 39    13    VA
# 40    14    NJ
# 41    15    NC
# 42    16    GA
# 43    16    MI
# 44    18    OH
# 45    20    PA
# 46    20    IL
# 47    29    NY
# 48    29    FL
# 49    38    TX
# 50    55    CA

# %%
scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

df['text'] = df['state'] 
    
data = [dict(
    type='choropleth',
    colorscale = scl,
    autocolorscale = False,
    locations = df['state'],
    z = df['votes'].astype(float),
    locationmode = 'USA-states',
    text = df['text'],
    hoverinfo = 'location+z',
    marker = dict(
        line = dict (
            color = 'rgb(255,255,255)',
            width = 2
        )
    ),
    colorbar = dict(
        title = "Votes"
    )
)]

layout = dict(
    title = '2016 Electoral College Votes<br>(Hover for breakdown)',
    geo = dict(
        scope='usa',
        projection=dict( type='albers usa' ),
        showlakes = True,
        lakecolor = 'rgb(255, 255, 255)'
    )
)
    
fig = dict(data=data, layout=layout)

py.iplot(fig, validate=False, filename='d3-electoral-map')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jlarsch/2.embed" height="525px" width="100%"></iframe>
